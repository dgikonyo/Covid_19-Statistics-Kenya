# %%
import pandas as pd
import numpy as np
covid_data=pd.read_csv('COVID19-Data.csv')

# %%
from scipy import stats

# %%
covid_data.head()
#confirming that our data has been imported
# Out:
#        ID     Updated  Confirmed  ConfirmedChange  Deaths  DeathsChange  \
# 0  338995  01/21/2020      262.0              NaN     0.0           NaN
# 1  338996  01/22/2020      313.0             51.0     0.0           0.0
# 2  338997  01/23/2020      578.0            265.0     0.0           0.0
# 3  338998  01/24/2020      841.0            263.0     0.0           0.0
# 4  338999  01/25/2020     1320.0            479.0     0.0           0.0
#
#    Recovered  RecoveredChange  Latitude  Longitude ISO2 ISO3 Country_Region  \
# 0        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
# 1        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
# 2        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
# 3        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
# 4        NaN              NaN       NaN        NaN  NaN  NaN      Worldwide
#
#   AdminRegion1 AdminRegion2
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
#Cleaning the data

#removing columns we don't need
columns_to_drop=['ConfirmedChange','DeathsChange',
                 'RecoveredChange','Latitude','Longitude','ISO2','ISO3','AdminRegion1','AdminRegion2']
covid_data.drop(columns_to_drop,inplace=True,axis=1)
#inplace tells our program that we want to manipulate the covid_data object

# %%
covid_data.head(100)
# Out:
#          ID     Updated  Confirmed    Deaths  Recovered Country_Region
# 0    338995  01/21/2020      262.0       0.0        NaN      Worldwide
# 1    338996  01/22/2020      313.0       0.0        NaN      Worldwide
# 2    338997  01/23/2020      578.0       0.0        NaN      Worldwide
# 3    338998  01/24/2020      841.0       0.0        NaN      Worldwide
# 4    338999  01/25/2020     1320.0       0.0        NaN      Worldwide
# ..      ...         ...        ...       ...        ...            ...
# 95  6955177  04/25/2020  2868539.0  201502.0   811660.0      Worldwide
# 96  7002306  04/26/2020  2965363.0  206265.0   863464.0      Worldwide
# 97  7055144  04/27/2020  3002303.0  208131.0   878813.0      Worldwide
# 98  7098114  04/28/2020  3083467.0  213824.0   915988.0      Worldwide
# 99  7520959  04/29/2020  3170335.0  224708.0   958353.0      Worldwide
#
# [100 rows x 6 columns]

# %%
covid_data['ID'].is_unique
#checking if values in 'ID' column are unique so as to make it our identifier
# Out:
# True

# %%
covid_data=covid_data.set_index('ID')
#setting the index to 'ID' since it's unique

# %%
covid_data.head(1000)
# Out:
#              Updated  Confirmed  Deaths  Recovered Country_Region
# ID
# 338995    01/21/2020      262.0     0.0        NaN      Worldwide
# 338996    01/22/2020      313.0     0.0        NaN      Worldwide
# 338997    01/23/2020      578.0     0.0        NaN      Worldwide
# 338998    01/24/2020      841.0     0.0        NaN      Worldwide
# 338999    01/25/2020     1320.0     0.0        NaN      Worldwide
# ...              ...        ...     ...        ...            ...
# 69664694  09/25/2020    13045.0   373.0     7309.0        Albania
# 70103884  09/26/2020    13153.0   375.0     7397.0        Albania
# 70512017  09/27/2020    13259.0   377.0     7534.0        Albania
# 70893024  09/28/2020    13391.0   380.0     7629.0        Albania
# 71254868  09/29/2020    13518.0   384.0     7732.0        Albania
#
# [1000 rows x 5 columns]

# %%
covid_data.dtypes.value_counts()
#we are checking for the daya types
# Out:
# float64    3
# object     2
# dtype: int64

# %%
covid_data=covid_data.loc[(covid_data['Country_Region']=='Kenya')]
#selecting only those rows that contain data from Kenya

# %%
covid_data.head()
# Out:
#             Updated  Confirmed  Deaths  Recovered Country_Region
# ID
# 7174960  03/13/2020        1.0     0.0        0.0          Kenya
# 7174962  03/14/2020        1.0     0.0        NaN          Kenya
# 7174964  03/15/2020        1.0     0.0        0.0          Kenya
# 7174965  03/16/2020        3.0     0.0        0.0          Kenya
# 7174966  03/17/2020        3.0     0.0        0.0          Kenya

# %%
covid_data=covid_data.dropna()
#dropping all rows with 'Nan' as a value

# %%
#checking for duplicate values
covid_data.drop_duplicates(['Updated'])
# Out:
#               Updated  Confirmed  Deaths  Recovered Country_Region
# ID
# 7174960    03/13/2020        1.0     0.0        0.0          Kenya
# 7174964    03/15/2020        1.0     0.0        0.0          Kenya
# 7174965    03/16/2020        3.0     0.0        0.0          Kenya
# 7174966    03/17/2020        3.0     0.0        0.0          Kenya
# 7174980    03/18/2020        7.0     0.0        0.0          Kenya
# ...               ...        ...     ...        ...            ...
# 122067117  03/07/2021   108827.0  1876.0    87570.0          Kenya
# 122067118  03/08/2021   109164.0  1879.0    87623.0          Kenya
# 122067119  03/09/2021   109643.0  1886.0    87623.0          Kenya
# 122067121  03/10/2021   110356.0  1898.0    87903.0          Kenya
# 122067122  03/11/2021   111185.0  1899.0    87994.0          Kenya
#
# [362 rows x 5 columns]

# %%
covid_data.describe()
# Out:
#            Confirmed       Deaths     Recovered
# count     362.000000   362.000000    362.000000
# mean    44168.066298   779.662983  32680.720994
# std     39771.378537   688.899252  32979.688567
# min         1.000000     0.000000      0.000000
# 25%      3343.000000    97.000000   1178.250000
# 50%     35709.500000   611.500000  21999.500000
# 75%     90809.750000  1578.500000  71497.750000
# max    111185.000000  1899.000000  87994.000000

# %%
print(covid_data['Updated'].dtype)
# Out:
# object

# %%
covid_data['Updated'] = pd.to_datetime(covid_data['Updated'], format='%m/%d/%Y')
#changing the data type of the data in 'Updated' column from a String to datetime

# %%
print(covid_data['Updated'].dtype)
# Out:
# datetime64[ns]

# %%
covid_data[(np.abs(stats.zscore(covid_data))<3).all(axis=1)]
#keeping values whose zscore is < 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-de69ff057064> in <module>
# ----> 1 covid_data[(np.abs(stats.zscore(covid_data))<3).all(axis=1)]
#       2 #keeping values whose zscore is < 3
#
# ~/.local/lib/python3.9/site-packages/scipy/stats/stats.py in zscore(a, axis, ddof, nan_policy)
#    2557             isconst = np.apply_along_axis(_isconst, axis, a)
#    2558     else:
# -> 2559         mn = a.mean(axis=axis, keepdims=True)
#    2560         std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    2561         if axis is None:
#
# /usr/lib/python3.9/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     176             is_float16_result = True
#     177
# --> 178     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     179     if isinstance(ret, mu.ndarray):
#     180         ret = um.true_divide(
#
# TypeError: unsupported operand type(s) for +: 'Timestamp' and 'Timestamp'

# %%
covid_data.head(1000)
# Out:
#              Updated  Confirmed  Deaths  Recovered Country_Region
# ID
# 7174960   2020-03-13        1.0     0.0        0.0          Kenya
# 7174964   2020-03-15        1.0     0.0        0.0          Kenya
# 7174965   2020-03-16        3.0     0.0        0.0          Kenya
# 7174966   2020-03-17        3.0     0.0        0.0          Kenya
# 7174980   2020-03-18        7.0     0.0        0.0          Kenya
# ...              ...        ...     ...        ...            ...
# 122067117 2021-03-07   108827.0  1876.0    87570.0          Kenya
# 122067118 2021-03-08   109164.0  1879.0    87623.0          Kenya
# 122067119 2021-03-09   109643.0  1886.0    87623.0          Kenya
# 122067121 2021-03-10   110356.0  1898.0    87903.0          Kenya
# 122067122 2021-03-11   111185.0  1899.0    87994.0          Kenya
#
# [362 rows x 5 columns]
